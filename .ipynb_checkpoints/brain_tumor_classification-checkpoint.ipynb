# %% [markdown]
# ### Load Modules

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
import numpy as np
import os
import cv2
from sklearn.model_selection import train_test_split
# Out:
# WARNING:tensorflow:From C:\Users\wahia\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ### Collect & Prepare Data

# %%
TEST_DIR = 'brain_tumor/Testing/'
TRAIN_DIR = 'brain_tumor/Training/'
IMG_SIZE = 128
CATEGORIES = ["glioma_tumor","meningioma_tumor","no_tumor","pituitary_tumor"]

# %%
def load_data(directory):
    data = []
    for category in CATEGORIES:
        path = os.path.join(directory, category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                data.append([new_array, class_num])
            except Exception as e:
                pass
    return data

# %%
training_data = load_data(TRAIN_DIR)
testing_data = load_data(TEST_DIR)

# %%
X_train = np.array([i[0] for i in training_data]).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
Y_train = np.array([i[1] for i in training_data])
X_test = np.array([i[0] for i in testing_data]).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
Y_test = np.array([i[1] for i in testing_data])

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ### Split Data

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42)

# %% [markdown]
# ### Train Model

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(4, activation='softmax')
])
# Out:
# WARNING:tensorflow:From C:\Users\wahia\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\wahia\anaconda3\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, batch_size=32, epochs=50,
                    validation_data=(X_val, Y_val))
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\wahia\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\wahia\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 72/72 [==============================] - 17s 223ms/step - loss: 1.0259 - accuracy: 0.5466 - val_loss: 0.8307 - val_accuracy: 0.6655
# Epoch 2/50
# 72/72 [==============================] - 16s 228ms/step - loss: 0.6328 - accuracy: 0.7487 - val_loss: 0.5714 - val_accuracy: 0.7648
# Epoch 3/50
# 72/72 [==============================] - 17s 234ms/step - loss: 0.4507 - accuracy: 0.8306 - val_loss: 0.4490 - val_accuracy: 0.8432
# Epoch 4/50
# 72/72 [==============================] - 17s 237ms/step - loss: 0.3458 - accuracy: 0.8637 - val_loss: 0.3870 - val_accuracy: 0.8449
# Epoch 5/50
# 72/72 [==============================] - 17s 242ms/step - loss: 0.2374 - accuracy: 0.9120 - val_loss: 0.3568 - val_accuracy: 0.8763
# Epoch 6/50
# 72/72 [==============================] - 18s 245ms/step - loss: 0.1752 - accuracy: 0.9399 - val_loss: 0.3253 - val_accuracy: 0.8780
# Epoch 7/50
# 72/72 [==============================] - 18s 248ms/step - loss: 0.1423 - accuracy: 0.9451 - val_loss: 0.3436 - val_accuracy: 0.8850
# Epoch 8/50
# 72/72 [==============================] - 18s 251ms/step - loss: 0.0981 - accuracy: 0.9678 - val_loss: 0.3516 - val_accuracy: 0.9077
# Epoch 9/50
# 72/72 [==============================] - 18s 255ms/step - loss: 0.0784 - accuracy: 0.9726 - val_loss: 0.2852 - val_accuracy: 0.9094
# Epoch 10/50
# 72/72 [==============================] - 19s 260ms/step - loss: 0.0588 - accuracy: 0.9804 - val_loss: 0.3333 - val_accuracy: 0.9181
# Epoch 11/50
# 72/72 [==============================] - 18s 257ms/step - loss: 0.0420 - accuracy: 0.9861 - val_loss: 0.3581 - val_accuracy: 0.9111
# Epoch 12/50
# 72/72 [==============================] - 18s 256ms/step - loss: 0.0439 - accuracy: 0.9821 - val_loss: 0.3670 - val_accuracy: 0.8990
# Epoch 13/50
# 72/72 [==============================] - 19s 260ms/step - loss: 0.0477 - accuracy: 0.9843 - val_loss: 0.2974 - val_accuracy: 0.9233
# Epoch 14/50
# 72/72 [==============================] - 19s 260ms/step - loss: 0.0361 - accuracy: 0.9891 - val_loss: 0.3384 - val_accuracy: 0.9146
# Epoch 15/50
# 72/72 [==============================] - 19s 261ms/step - loss: 0.0340 - accuracy: 0.9865 - val_loss: 0.3588 - val_accuracy: 0.9181
# Epoch 16/50
# 72/72 [==============================] - 19s 261ms/step - loss: 0.0309 - accuracy: 0.9891 - val_loss: 0.3653 - val_accuracy: 0.8972
# Epoch 17/50
# 72/72 [==============================] - 19s 260ms/step - loss: 0.0185 - accuracy: 0.9952 - val_loss: 0.4212 - val_accuracy: 0.9094
# Epoch 18/50
# 72/72 [==============================] - 19s 264ms/step - loss: 0.0156 - accuracy: 0.9952 - val_loss: 0
ms/step - loss: 0.0125 - accuracy: 0.9961 - val_loss: 0.3910 - val_accuracy: 0.9199
# Epoch 44/50
# 72/72 [==============================] - 20s 273ms/step - loss: 0.0054 - accuracy: 0.9978 - val_loss: 0.4170 - val_accuracy: 0.9233
# Epoch 45/50
# 72/72 [==============================] - 20s 271ms/step - loss: 0.0204 - accuracy: 0.9922 - val_loss: 0.4104 - val_accuracy: 0.9303
# Epoch 46/50
# 72/72 [==============================] - 20s 279ms/step - loss: 0.0291 - accuracy: 0.9900 - val_loss: 0.4577 - val_accuracy: 0.9059
# Epoch 47/50
# 72/72 [==============================] - 20s 274ms/step - loss: 0.0519 - accuracy: 0.9882 - val_loss: 0.4735 - val_accuracy: 0.9024
# Epoch 48/50
# 72/72 [==============================] - 20s 276ms/step - loss: 0.0138 - accuracy: 0.9952 - val_loss: 0.4068 - val_accuracy: 0.9321
# Epoch 49/50
# 72/72 [==============================] - 20s 273ms/step - loss: 0.0112 - accuracy: 0.9961 - val_loss: 0.4404 - val_accuracy: 0.9286
# Epoch 50/50
# 72/72 [==============================] - 20s 273ms/step - loss: 0.0150 - accuracy: 0.9943 - val_loss: 0.3968 - val_accuracy: 0.9164

# %%
selected_folder = "brain_tumor/Testing/glioma_tumor"  
image_files = os.listdir(selected_folder)

selected_image_filename = image_files[7] 

selected_image_path = os.path.join(selected_folder, selected_image_filename)
selected_image = cv2.imread(selected_image_path)
selected_image = cv2.resize(selected_image, (IMG_SIZE, IMG_SIZE))  
selected_image = selected_image / 255.0  

selected_image = selected_image.reshape(1, IMG_SIZE, IMG_SIZE, 3)

predictions = model.predict(selected_image)

predicted_class_index = np.argmax(predictions)
predicted_class = CATEGORIES[predicted_class_index]

print("Predicted class:", predicted_class)
# Out:
# 1/1 [==============================] - 0s 111ms/step
# Predicted class: glioma_tumor

# %%
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC

X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_val_flat = X_val.reshape(X_val.shape[0], -1)
X_test_flat = X_test.reshape(X_test.shape[0], -1)

svm_classifier = SVC(kernel='linear', C=1.0, random_state=42)
svm_classifier.fit(X_train_flat, Y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
selected_folder = "brain_tumor/Testing/meningioma_tumor"  
image_files = os.listdir(selected_folder)

selected_image_filename = image_files[78] 

selected_image_path = os.path.join(selected_folder, selected_image_filename)
selected_image = cv2.imread(selected_image_path)
selected_image = cv2.resize(selected_image, (IMG_SIZE, IMG_SIZE))  
selected_image = selected_image / 255.0  
selected_image_flat = selected_image.reshape(1, -1) 

svm_predicted_class_index = svm_classifier.predict(selected_image_flat)[0]
svm_predicted_class = CATEGORIES[svm_predicted_class_index]

print("Predicted class:", svm_predicted_class)
# Out:
# Predicted class: meningioma_tumor

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

pca = PCA(n_components=100) 
X_train_pca = pca.fit_transform(X_train_flat)
X_test_pca = pca.transform(X_test_flat)

knn_grid = GridSearchCV(KNeighborsClassifier(), {'n_neighbors': [3, 5, 7]}, cv=5)
knn_grid.fit(X_train_pca, Y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7]})

# %%
selected_folder = "brain_tumor/Testing/no_tumor"  
image_files = os.listdir(selected_folder)

selected_image_filename = image_files[39] 

selected_image_path = os.path.join(selected_folder, selected_image_filename)
selected_image = cv2.imread(selected_image_path)
selected_image = cv2.resize(selected_image, (IMG_SIZE, IMG_SIZE))  
selected_image = selected_image / 255.0  
selected_image_flat = selected_image.reshape(1, -1) 
selected_image_pca = pca.transform(selected_image_flat)

knn_best_model = knn_grid.best_estimator_

knn_predicted_class_index = knn_best_model.predict(selected_image_pca)[0]
knn_predicted_class = CATEGORIES[knn_predicted_class_index]

print("Predicted class:", knn_predicted_class)
# Out:
# Predicted class: no_tumor

# %%
from sklearn.ensemble import RandomForestClassifier

X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_val_flat = X_val.reshape(X_val.shape[0], -1)
X_test_flat = X_test.reshape(X_test.shape[0], -1)

rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train_flat, Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
selected_folder = "brain_tumor/Testing/pituitary_tumor"  
image_files = os.listdir(selected_folder)

selected_image_filename = image_files[17] 

selected_image_path = os.path.join(selected_folder, selected_image_filename)
selected_image = cv2.imread(selected_image_path)
selected_image = cv2.resize(selected_image, (IMG_SIZE, IMG_SIZE))  
selected_image = selected_image / 255.0  
selected_image_flat = selected_image.reshape(1, -1)  

rf_predicted_class_index = rf_classifier.predict(selected_image_flat)[0]
rf_predicted_class = CATEGORIES[rf_predicted_class_index]

print("Predicted class:", rf_predicted_class)
# Out:
# Predicted class: pituitary_tumor

# %%
from sklearn.tree import DecisionTreeClassifier

dt_classifier = DecisionTreeClassifier(random_state=42)
dt_classifier.fit(X_train_flat, Y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
selected_folder = "brain_tumor/Testing/meningioma_tumor"  
image_files = os.listdir(selected_folder)

selected_image_filename = image_files[55] 

selected_image_path = os.path.join(selected_folder, selected_image_filename)
selected_image = cv2.imread(selected_image_path)
selected_image = cv2.resize(selected_image, (IMG_SIZE, IMG_SIZE))  
selected_image = selected_image / 255.0  
selected_image_flat = selected_image.reshape(1, -1)  

dt_predicted_class_index = dt_classifier.predict(selected_image_flat)[0]
dt_predicted_class = CATEGORIES[dt_predicted_class_index]

print("Predicted class:", dt_predicted_class)
# Out:
# Predicted class: meningioma_tumor

# %% [markdown]
# ### Evaluation

# %%
test_loss, test_accuracy = model.evaluate(X_test, Y_test)
print("Testing Loss:", test_loss)
print("Testing Accuracy:", test_accuracy)
# Out:
# 8/8 [==============================] - 1s 42ms/step - loss: 0.2777 - accuracy: 0.9488
# Testing Loss: 0.2777363061904907
# Testing Accuracy: 0.9488189220428467

# %%
svm_pred = svm_classifier.predict(X_test_flat)
svm_accuracy = accuracy_score(Y_test, svm_pred)
print("SVM Accuracy:", svm_accuracy)
# Out:
# SVM Accuracy: 0.9212598425196851

# %%
knn_best_model = knn_grid.best_estimator_
knn_accuracy = knn_best_model.score(X_test_pca, Y_test)
print("KNN Accuracy:", knn_accuracy)
# Out:
# KNN Accuracy: 0.7125984251968503

# %%
rf_pred = rf_classifier.predict(X_test_flat)
rf_accuracy = accuracy_score(Y_test, rf_pred)
print("Random Forest Accuracy:", rf_accuracy)
# Out:
# Random Forest Accuracy: 0.8661417322834646

# %%
dt_pred = dt_classifier.predict(X_test_flat)
dt_accuracy = accuracy_score(Y_test, dt_pred)
print("Decision Tree Accuracy:", dt_accuracy)
# Out:
# Decision Tree Accuracy: 0.8700787401574803

# %%
import matplotlib.pyplot as plt

accuracies = [test_accuracy, rf_accuracy, knn_accuracy, svm_accuracy, dt_accuracy]

models = ['CNN', 'Random Forest', 'KNN', 'SVM', 'Decision Tree']

plt.figure(figsize=(10, 5))
plt.barh(models, accuracies, color='skyblue')
plt.xlabel('Test Accuracy')
plt.ylabel('Models')
plt.title('Test Accuracies of Various Models')
plt.xlim(0, 1)
for i, accuracy in enumerate(accuracies):
    plt.text(accuracy + 0.01, i, f'{accuracy:.4f}', va='center')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

Y_pred = np.argmax(model.predict(X_test), axis=-1)
cnn_cm = confusion_matrix(Y_test, Y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cnn_cm, annot=True, fmt='d', cmap='Blues', xticklabels=CATEGORIES, yticklabels=CATEGORIES)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for CNN')
plt.show()
# Out:
# 8/8 [==============================] - 0s 43ms/step

# %%
svm_cm = confusion_matrix(Y_test, svm_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(svm_cm, annot=True, fmt='d', cmap='Blues', xticklabels=CATEGORIES, yticklabels=CATEGORIES)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for SVM')
plt.show()

# %%
knn_pred = knn_best_model.predict(X_test_pca)
knn_cm = confusion_matrix(Y_test, knn_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(knn_cm, annot=True, fmt='d', cmap='Blues', xticklabels=CATEGORIES, yticklabels=CATEGORIES)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for KNN')
plt.show()

# %%
rf_cm = confusion_matrix(Y_test, rf_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(rf_cm, annot=True, fmt='d', cmap='Blues', xticklabels=CATEGORIES, yticklabels=CATEGORIES)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for Random Forest')
plt.show()

# %%
dt_cm = confusion_matrix(Y_test, dt_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(dt_cm, annot=True, fmt='d', cmap='Blues', xticklabels=CATEGORIES, yticklabels=CATEGORIES)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for Decision Tree')
plt.show()

# %% [markdown]
# ### Test Model

# %%
dec = {0:'glioma_tumor', 1:'meningioma_tumor', 2:'no_tumor', 3:'pituitary_tumor'}

# %%
import pickle
pickle.dump(model,open('model.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17144\1247235325.py in <module>
#       1 import pickle
# ----> 2 pickle.dump(model,open('model.pkl','wb'))
#
# NameError: name 'model' is not defined
